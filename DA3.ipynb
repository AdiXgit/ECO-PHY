# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA

data = pd.read_excel('J1newdata.xlsx',index_col='MONTH',parse_dates = True)
# Out:
# C:\Users\Aditya Dwaraki Rao\AppData\Local\Temp\ipykernel_13852\1217182739.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_excel('J1newdata.xlsx',index_col='MONTH',parse_dates = True)

# %%
#basic time series plot
data['AVERAGE'].plot(figsize = (15,8))
# Out:
# <Axes: xlabel='MONTH'>
